# %%
# Dzień 5 Pandas - Obróbka danych - Część 1 - Duplikaty

import pandas as pd
df = pd.read_csv(
  r'C:\Users\damia\Desktop\coderslab - Data scientist\3. Pandas\Zjazd_3_-_pliki_do_zadań\Zjazd 3 - pliki do zadań\01_Dane\ceny_produktow_renamed.csv',
  sep=';',
  encoding='UTF-8',
  decimal='.'
)
df.head()
# Out:
#               province product_types currency  product_group_id  \
# 0         PODKARPACKIE           NaN       zł                 2
# 1              ŁÓDZKIE           NaN       zł                 4
# 2   KUJAWSKO-POMORSKIE           NaN       zł                 2
# 3         DOLNOŚLĄSKIE           NaN       zł                 2
# 4  WARMIŃSKO-MAZURSKIE           NaN       zł                 2
#
#                          product_line  value     date
# 0  szynka wieprzowa gotowana - za 1kg  21.37   2013-3
# 1                      chleb - za 1kg    NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg   3.55  2019-12
# 3        kurczęta patroszone - za 1kg   6.14   2019-2
# 4            salceson Włoski - za 1kg   5.63   2002-3

# %%
df.drop_duplicates()
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149933              ŚLĄSKIE
# 149934              ŚLĄSKIE
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149938  WARMIŃSKO-MAZURSKIE
#
#                                             product_types currency  \
# 0                                                     NaN       zł
# 1                                                     NaN       zł
# 2                                                     NaN       zł
# 3                                                     NaN       zł
# 4                                                     NaN       zł
# ...                                                   ...      ...
# 149933                                                NaN       zł
# 149934                                                NaN       zł
# ...

# %%
# 1. sprawdź, ile wierszy jest zduplikowanych.
is_duplicated = df.duplicated() # generujemy Series
df.loc[is_duplicated]
# Out:
#                    province product_types currency  product_group_id  \
# 545                 ŚLĄSKIE           NaN       zł                 4
# 1913               LUBUSKIE           NaN       zł                 4
# 2356                 POLSKA           NaN       zł                 4
# 2528    WARMIŃSKO-MAZURSKIE           NaN       zł                 4
# 2662         ŚWIĘTOKRZYSKIE           NaN       zł                 4
# ...                     ...           ...      ...               ...
# 149925        WIELKOPOLSKIE           NaN       zł                 4
# 149926               POLSKA           NaN       zł                 4
# 149930  WARMIŃSKO-MAZURSKIE           NaN       zł                 4
# 149937          MAŁOPOLSKIE           NaN       zł                 4
# 149939          MAZOWIECKIE           NaN       zł                 4
#
#                                           product_line  value     date
# ...

# %%
# lub
df.loc[df.duplicated()]
# Out:
#                    province product_types currency  product_group_id  \
# 545                 ŚLĄSKIE           NaN       zł                 4
# 1913               LUBUSKIE           NaN       zł                 4
# 2356                 POLSKA           NaN       zł                 4
# 2528    WARMIŃSKO-MAZURSKIE           NaN       zł                 4
# 2662         ŚWIĘTOKRZYSKIE           NaN       zł                 4
# ...                     ...           ...      ...               ...
# 149925        WIELKOPOLSKIE           NaN       zł                 4
# 149926               POLSKA           NaN       zł                 4
# 149930  WARMIŃSKO-MAZURSKIE           NaN       zł                 4
# 149937          MAŁOPOLSKIE           NaN       zł                 4
# 149939          MAZOWIECKIE           NaN       zł                 4
#
#                                           product_line  value     date
# ...
