# %%
# Dzień 5 - Pandas - Obróbka danych - część 1 - Modyfikacja nazw kolumn

import pandas as pd
df = pd.read_csv(
  r'C:\Users\damia\Desktop\coderslab - Data scientist\3. Pandas\Zjazd_3_-_pliki_do_zadań\Zjazd 3 - pliki do zadań\01_Dane\ceny_produktow.csv',
  sep=';',
  encoding='UTF-8',
  decimal='.'
)
df.head()
# Out:
#                  Nazwa Rodzaje towarów Jednostka miary  ID grupy  \
# 0         PODKARPACKIE             NaN              zł         2
# 1              ŁÓDZKIE             NaN              zł         4
# 2   KUJAWSKO-POMORSKIE             NaN              zł         2
# 3         DOLNOŚLĄSKIE             NaN              zł         2
# 4  WARMIŃSKO-MAZURSKIE             NaN              zł         2
#
#                     Rodzaje produktów  Wartosc     Data
# 0  szynka wieprzowa gotowana - za 1kg    21.37   2013-3
# 1                      chleb - za 1kg      NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg     3.55  2019-12
# 3        kurczęta patroszone - za 1kg     6.14   2019-2
# 4            salceson Włoski - za 1kg     5.63   2002-3

# %%
# rename
df.rename(columns = {
    'Nazwa': 'province',
    'Rodzaje towarów': 'product_types',
    'Jednostka miary': 'currency',
    'ID grupy': 'id',
    'Rodzaje produktów': 'product_line',
    'Wartosc': 'value',
    'Data': 'date'
})
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                             product_types currency  id  \
# 0                                                     NaN       zł   2
# 1                                                     NaN       zł   4
# 2                                                     NaN       zł   2
# 3                                                     NaN       zł   2
# 4                                                     NaN       zł   2
# ...                                                   ...      ...  ..
# 149935                                                NaN       zł   2
# ...

# %%
# columns

df3 = df.copy()
df3.columns=('province', 'product_types','currency', 'id', 'product_line', 'value', 'date')
df3
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                             product_types currency  id  \
# 0                                                     NaN       zł   2
# 1                                                     NaN       zł   4
# 2                                                     NaN       zł   2
# 3                                                     NaN       zł   2
# 4                                                     NaN       zł   2
# ...                                                   ...      ...  ..
# 149935                                                NaN       zł   2
# ...

# %%
# alternatywa

cols_dict = {
    'Nazwa': 'province',
    'Rodzaje towarów': 'product_types',
    'Jednostka miary': 'currency',
    'ID grupy': 'id',
    'Rodzaje produktów': 'product_line',
    'Wartosc': 'value',
    'Data': 'date'
}

df_renamed = df.rename(columns=cols_dict)
df_renamed

cols = list(cols_dict.values())
cols

df_renamed_2 = df.copy()
df_renamed_2.columns = cols
df_renamed_2
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                             product_types currency  id  \
# 0                                                     NaN       zł   2
# 1                                                     NaN       zł   4
# 2                                                     NaN       zł   2
# 3                                                     NaN       zł   2
# 4                                                     NaN       zł   2
# ...                                                   ...      ...  ..
# 149935                                                NaN       zł   2
# ...
